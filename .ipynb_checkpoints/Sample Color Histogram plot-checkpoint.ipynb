# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

nb_bins = 256
count_r = np.zeros(nb_bins)
count_g = np.zeros(nb_bins)
count_b = np.zeros(nb_bins)

img = Image.open('/Users/h383kim/pytorch/AlexNet/splitted/train/cane/OIF-e2bexWrojgtQnAPPcUfOWQ.jpeg')

# Calculate manual hist
x = np.array(img)
x = x.transpose(2, 0, 1)
hist_r = np.histogram(x[0], bins=nb_bins, range=[0, 255])
hist_g = np.histogram(x[1], bins=nb_bins, range=[0, 255])
hist_b = np.histogram(x[2], bins=nb_bins, range=[0, 255])
count_r = hist_r[0]
count_g = hist_g[0]
count_b = hist_b[0]


# Plot matplotlib
fig2 = plt.figure()
plt.hist(x[0].ravel(), bins = 256, color = 'red', alpha = 0.5)
plt.hist(x[1].ravel(), bins = 256, color = 'green', alpha = 0.5)
plt.hist(x[2].ravel(), bins = 256, color = 'blue', alpha = 0.5)
# Out:
# (array([2.700e+01, 2.000e+00, 2.000e+00, 3.000e+00, 1.100e+01, 8.000e+00,
#         8.000e+00, 1.000e+01, 1.200e+01, 1.000e+01, 1.100e+01, 1.500e+01,
#         1.900e+01, 3.200e+01, 5.300e+01, 7.500e+01, 7.600e+01, 9.700e+01,
#         1.060e+02, 1.300e+02, 1.440e+02, 1.660e+02, 2.260e+02, 2.530e+02,
#         2.510e+02, 2.320e+02, 2.280e+02, 2.190e+02, 2.250e+02, 2.460e+02,
#         2.970e+02, 3.870e+02, 3.700e+02, 5.200e+02, 4.360e+02, 4.220e+02,
#         4.010e+02, 4.000e+02, 3.450e+02, 3.220e+02, 2.840e+02, 2.540e+02,
#         2.360e+02, 2.130e+02, 2.130e+02, 1.920e+02, 2.000e+02, 1.990e+02,
#         1.440e+02, 1.670e+02, 1.610e+02, 1.430e+02, 1.660e+02, 1.620e+02,
#         1.510e+02, 1.480e+02, 1.000e+02, 1.440e+02, 1.180e+02, 1.150e+02,
#         1.040e+02, 1.290e+02, 1.050e+02, 1.340e+02, 1.030e+02, 1.260e+02,
#         9.700e+01, 1.190e+02, 1.250e+02, 1.230e+02, 1.190e+02, 1.030e+02,
#         1.000e+02, 1.210e+02, 1.100e+02, 9.900e+01, 1.310e+02, 1.080e+02,
# ...
